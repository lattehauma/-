# %% [markdown]
# <a href="https://colab.research.google.com/github/lattehauma/-/blob/main/%EC%9D%B8%EC%B2%9C%EB%B2%84%EC%8A%A4%EB%85%B8%EC%84%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('/content/인천광역시_버스노선별 정류장 현황_20220512.csv', encoding='cp949')
data2 = pd.read_csv('/content/인천광역시_시내버스 정류소 현황_20220516.csv', encoding='cp949')

# %%
data.head()
# Out:
#          기준일자   회사명   회사아이디 노선번호      노선아이디  순번    정류소명  정류소번호     정류소아이디  \
# 0  2022-05-12  강인교통  166012  302  165000067   1  십정동차고지  40913  166000913
# 1  2022-05-12  강인교통  166012  302  165000067   2   십정사거리  40029  166000029
# 2  2022-05-12  강인교통  166012  302  165000067   3  선린감리교회  40043  166000043
# 3  2022-05-12  강인교통  166012  302  165000067   4   백영아파트  40058  166000058
# 4  2022-05-12  강인교통  166012  302  165000067   5     상정고  40069  166000069
#
#    아이에스씨 아이디  정류소구간거리  정류소간누적거리 주요경유지여부 상_하행
# 0  2807789.0      0.0       0.0       N   상행
# 1  2801793.0    560.0     560.0       Y   상행
# 2  2801779.0    245.0     805.0       Y   상행
# 3  2801766.0    363.0    1168.0       Y   상행
# 4  2801756.0    371.0    1539.0       N   상행

# %%
data2.head()
# Out:
#          기준일자       정류소 명   정류소 번호     정류소 ID    권역 행정동 명         X 좌표  \
# 0  2022-05-16  (구)국제여객터미널  35052.0  161000052    중구   연안동  164354.2093
# 1  2022-05-16  (구)국제여객터미널  35051.0  161000051    중구   연안동  164336.1312
# 2  2022-05-16  (구)시민회관사거리  37319.0  163000319  미추홀구  주안4동  171634.3433
# 3  2022-05-16  (구)시민회관사거리  37326.0  163000326  미추홀구  주안2동  171611.3811
# 4  2022-05-16     (구)신현주공  42228.0  168000228    서구  가정1동  171058.1950
#
#            위도         Y 좌표         경도
# 0  126.597932  438993.8440  37.452415
# 1  126.597726  439026.3601  37.452707
# 2  126.680188  439514.7790  37.457360
# 3  126.679927  439559.9220  37.457766
# 4  126.673395  446673.6356  37.521843

# %%
num_list=['202','203','204','205','206','222','111','117','302','303','303-1','304','306',
          '307','308','310','320','330','6777','202A','222A','222B','223A','111B','306A']
df=data[data['노선번호'].isin(num_list)]

# %%
df.head()
# Out:
#          기준일자   회사명   회사아이디 노선번호      노선아이디  순번    정류소명  정류소번호     정류소아이디  \
# 0  2022-05-12  강인교통  166012  302  165000067   1  십정동차고지  40913  166000913
# 1  2022-05-12  강인교통  166012  302  165000067   2   십정사거리  40029  166000029
# 2  2022-05-12  강인교통  166012  302  165000067   3  선린감리교회  40043  166000043
# 3  2022-05-12  강인교통  166012  302  165000067   4   백영아파트  40058  166000058
# 4  2022-05-12  강인교통  166012  302  165000067   5     상정고  40069  166000069
#
#    아이에스씨 아이디  정류소구간거리  정류소간누적거리 주요경유지여부 상_하행
# 0  2807789.0      0.0       0.0       N   상행
# 1  2801793.0    560.0     560.0       Y   상행
# 2  2801779.0    245.0     805.0       Y   상행
# 3  2801766.0    363.0    1168.0       Y   상행
# 4  2801756.0    371.0    1539.0       N   상행

# %%
import seaborn as sns

# %%
df.정류소아이디.value_counts().head(20)
# Out:
# 166000913    18
# 161000207    13
# 161000026    12
# 161000203    12
# 161000205    11
# 161000556    11
# 161000032    10
# 168000299    10
# 168001034     9
# 161000614     9
# 161000615     9
# 168001287     9
# 168000297     8
# 168001029     8
# 161000756     8
# 161000451     8
# 161000634     8
# 161000660     8
# 161000452     8
# 161000661     8
# Name: 정류소아이디, dtype: int64

# %%
num_list
# Out:
# ['202',
#  '203',
#  '204',
#  '205',
#  '206',
#  '222',
#  '111',
#  '117',
#  '302',
#  '303',
#  '303-1',
#  '304',
#  '306',
#  '307',
#  '308',
#  '310',
#  '320',
#  '330',
#  '6777',
#  '202A',
#  '222A',
#  '222B',
#  '223A',
#  '111B',
#  '306A']

# %%
data302=data[data['노선번호']=='302']

# %%
id302=data302['정류소아이디']

# %%
join302 = pd.merge(id302, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')

# %%
join302
# Out:
#         정류소아이디        기준일자   정류소 명   정류소 번호     정류소 ID   권역 행정동 명  \
# 0    166000913  2022-05-16  십정동차고지  40913.0  166000913  부평구   십정동
# 1    166000029  2022-05-16   십정사거리  40029.0  166000029  부평구  십정1동
# 2    166000043  2022-05-16  선린감리교회  40043.0  166000043  부평구  십정1동
# 3    166000058  2022-05-16   백영아파트  40058.0  166000058  부평구  십정1동
# 4    166000069  2022-05-16     상정고  40069.0  166000069  부평구  십정1동
# ..         ...         ...     ...      ...        ...  ...   ...
# 103  166000070  2022-05-16     상정고  40070.0  166000070  부평구  십정1동
# 104  166000059  2022-05-16   상정중학교  40059.0  166000059  부평구  십정1동
# 105  166000047  2022-05-16  선린감리교회  40047.0  166000047  부평구  십정1동
# 106  166000033  2022-05-16   십정사거리  40033.0  166000033  부평구  십정1동
# 107  166000913  2022-05-16  십정동차고지  40913.0  166000913  부평구   십정동
#
#             X 좌표          위도         Y 좌표         경도
# 0    172571.6550  126.690710  441440.5107  37.474739
# 1    172698.6018  126.692147  441392.1633  37.474308
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as  sns
plt.figure(figsize=(11,11))
a=sns.scatterplot(x='X 좌표',y='Y 좌표',data=join302)
a.set(xlim=(153780, 164300),ylim=(439989, 448051))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data223=data[data['노선번호']=='223']
id223=data223['정류소아이디']
join223 = pd.merge(id223, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')

# %%
data320=data[data['노선번호']=='320']
id320=data320['정류소아이디']
join320 = pd.merge(id320, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')

# %%
data307=data[data['노선번호']=='307']
id307=data307['정류소아이디']
join307 = pd.merge(id307, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')

# %%
data304=data[data['노선번호']=='304']
id304=data304['정류소아이디']
join304 = pd.merge(id304, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')

# %%
data206=data[data['노선번호']=='206']
id206=data206['정류소아이디']
join206 = pd.merge(id206, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')
data205=data[data['노선번호']=='205']
id205=data205['정류소아이디']
join205 = pd.merge(id205, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')
data204=data[data['노선번호']=='204']
id204=data204['정류소아이디']
join204 = pd.merge(id204, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')
data203=data[data['노선번호']=='203']
id203=data203['정류소아이디']
join203 = pd.merge(id203, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')
data202=data[data['노선번호']=='202']
id202=data202['정류소아이디']
join202 = pd.merge(id202, data2, left_on='정류소아이디', right_on='정류소 ID', how='left')

# %%
plt.figure(figsize=(15,15))
a=sns.scatterplot(x='X 좌표',y='Y 좌표',data=join223, alpha=0.14, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join320, alpha=0.07, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join307, alpha=0.1, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join304, alpha=0.07, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join206, alpha=0.13, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join205, alpha=0.09, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join204, alpha=0.03, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join203, alpha=0.18, color='blue')
sns.scatterplot(x='X 좌표',y='Y 좌표',data=join202, alpha=0.17, color='blue')



a.set(xlim=(153780, 163700),ylim=(439989, 447651))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51340 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0, flags=flags)
